# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
datalatih = pd.read_excel("data mata kuliah wajib.xlsx")
datalatih.head(11)
# Out:
#                Jurusan  Pancasila  Bahasa Inggris  Bahasa Indonesia  Semester
# 0   Teknik Informatika        100              69                80         3
# 1   Teknik Informatika         90              78                89         1
# 2   Teknik Informatika         80              90                87         2
# 3      Ilmu Komunikasi         70              65                79         1
# 4      Ilmu Komunikasi         95              95                86         1
# 5             Biomedis         85              85                83         2
# 6     Sastra Indonesia         75              76                82         2
# 7     Sastra Indonesia         89              89                81         1
# 8        Sastra Jepang         79              85                76         1
# 9        Sastra Jepang         95              83                74         2
# 10       Sastra Jepang         77              72                74         2

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Jurusan           11 non-null     object
#  1   Pancasila         11 non-null     int64
#  2   Bahasa Inggris    11 non-null     int64
#  3   Bahasa Indonesia  11 non-null     int64
#  4   Semester          11 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 568.0+ bytes

# %%
from sklearn.cluster import KMeans
plt.scatter(datalatih.Pancasila, datalatih.Semester, s = 50, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["Jurusan"], axis=1)
x.head(11)
# Out:
#     Pancasila  Bahasa Inggris  Bahasa Indonesia  Semester
# 0         100              69                80         3
# 1          90              78                89         1
# 2          80              90                87         2
# 3          70              65                79         1
# 4          95              95                86         1
# 5          85              85                83         2
# 6          75              76                82         2
# 7          89              89                81         1
# 8          79              85                76         1
# 9          95              83                74         2
# 10         77              72                74         2

# %%
y = datalatih["Jurusan"]
y.head(11)
# Out:
# 0     Teknik Informatika
# 1     Teknik Informatika
# 2     Teknik Informatika
# 3        Ilmu Komunikasi
# 4        Ilmu Komunikasi
# 5               Biomedis
# 6       Sastra Indonesia
# 7       Sastra Indonesia
# 8          Sastra Jepang
# 9          Sastra Jepang
# 10         Sastra Jepang
# Name: Jurusan, dtype: object

# %%
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB

modelnb = GaussianNB()

nbtrain = modelnb.fit(x, y)
datauji = pd.read_excel("data mata kuliah wajib.xlsx")
datauji.head(11)
# Out:
#                Jurusan  Pancasila  Bahasa Inggris  Bahasa Indonesia  Semester
# 0   Teknik Informatika        100              69                80         3
# 1   Teknik Informatika         90              78                89         1
# 2   Teknik Informatika         80              90                87         2
# 3      Ilmu Komunikasi         70              65                79         1
# 4      Ilmu Komunikasi         95              95                86         1
# 5             Biomedis         85              85                83         2
# 6     Sastra Indonesia         75              76                82         2
# 7     Sastra Indonesia         89              89                81         1
# 8        Sastra Jepang         79              85                76         1
# 9        Sastra Jepang         95              83                74         2
# 10       Sastra Jepang         77              72                74         2

# %%
x_test = datauji.drop(["Jurusan"], axis=1)
x_test.head(11)
# Out:
#     Pancasila  Bahasa Inggris  Bahasa Indonesia  Semester
# 0         100              69                80         3
# 1          90              78                89         1
# 2          80              90                87         2
# 3          70              65                79         1
# 4          95              95                86         1
# 5          85              85                83         2
# 6          75              76                82         2
# 7          89              89                81         1
# 8          79              85                76         1
# 9          95              83                74         2
# 10         77              72                74         2

# %%
y_uji = datauji["Jurusan"]
y_uji.head(11)
# Out:
# 0     Teknik Informatika
# 1     Teknik Informatika
# 2     Teknik Informatika
# 3        Ilmu Komunikasi
# 4        Ilmu Komunikasi
# 5               Biomedis
# 6       Sastra Indonesia
# 7       Sastra Indonesia
# 8          Sastra Jepang
# 9          Sastra Jepang
# 10         Sastra Jepang
# Name: Jurusan, dtype: object

# %%
Y_predict = nbtrain.predict(x_test)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# Prediksi Naive Bayes :  ['Teknik Informatika' 'Ilmu Komunikasi' 'Teknik Informatika'
#  'Ilmu Komunikasi' 'Ilmu Komunikasi' 'Biomedis' 'Sastra Indonesia'
#  'Ilmu Komunikasi' 'Ilmu Komunikasi' 'Sastra Jepang' 'Sastra Jepang']

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_uji, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# Akurasi Naive Bayes :  0.7272727272727273

# %%
from sklearn.metrics import classification_report
print(classification_report(y_uji, Y_predict))
# Out:
#                     precision    recall  f1-score   support
#
#           Biomedis       1.00      1.00      1.00         1
#    Ilmu Komunikasi       0.40      1.00      0.57         2
#   Sastra Indonesia       1.00      0.50      0.67         2
#      Sastra Jepang       1.00      0.67      0.80         3
# Teknik Informatika       1.00      0.67      0.80         3
#
#           accuracy                           0.73        11
#          macro avg       0.88      0.77      0.77        11
#       weighted avg       0.89      0.73      0.75        11
